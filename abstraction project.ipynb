# %%
from abc import ABC, abstractmethod

class BuildingSystem(ABC):       # Abstract Class

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

    @abstractmethod
    def status(self):
        pass


class AirConditioningSystem(BuildingSystem):      # Child Class 1

    def start(self):
        print("Air Conditioning System started.")

    def stop(self):
        print("Air Conditioning System stopped.")

    def status(self):
        print("Air Conditioning System is running.")


class LightingSystem(BuildingSystem):          # Child Class 2

    def start(self):
        print("Lighting System switched on.")

    def stop(self):
        print("Lighting System switched off.")

    def status(self):
        print("Lighting System is active.")


class SecuritySystem(BuildingSystem):      # Child Class 3

    def start(self):
        print("Security System activated.")

    def stop(self):
        print("Security System deactivated.")

    def status(self):
        print("Security System is monitoring.")


class FireAlarmSystem(BuildingSystem):              # New Child Class

    def start(self):
        print("Fire Alarm System activated.")

    def stop(self):
        print("Fire Alarm System deactivated.")

    def status(self):
        print("Fire Alarm System is on standby.")


# objects
systems = [
    AirConditioningSystem(),
    LightingSystem(),
    SecuritySystem(),
    FireAlarmSystem()
]

# Demonstrate polymorphism
for system in systems:
    system.start()
    system.status()
    system.stop()
# Out:
# Air Conditioning System started.
# Air Conditioning System is running.
# Air Conditioning System stopped.
# Lighting System switched on.
# Lighting System is active.
# Lighting System switched off.
# Security System activated.
# Security System is monitoring.
# Security System deactivated.
# Fire Alarm System activated.
# Fire Alarm System is on standby.
# Fire Alarm System deactivated.
